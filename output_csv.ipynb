# %%
#!/usr/bin/env python
# coding: utf-8

import csv
import pandas as pd


r4_l1=pd.read_csv("./raw/sheets/R4コアカリ提出用/第1層.csv")
r4_l2=pd.read_csv("./raw/sheets/R4コアカリ提出用/第2層.csv")

columns=["第2層","第3層","第4層","メモ","H28対応項目"]
r4_l234 = pd.DataFrame(data=[],columns=columns)
tabs=r4_l1["タブ名"]
for tab in tabs:
    r4_l34_unit=pd.read_csv(f"./raw/sheets/R4コアカリ提出用/{tab}.csv")
    r4_l234=pd.concat([r4_l234,r4_l34_unit.loc[:,columns]])

r4_l12=pd.merge(r4_l1,r4_l2,how="outer").rename(columns={"メモ":"第2層メモ"})
r4_full=pd.merge(r4_l12,r4_l234,how="outer")
r4_full=r4_full.dropna(subset=["第1層","第2層","第3層","第4層"])

r4_no_disc=r4_full.loc[:,["第1層","第2層","第3層","第4層"]]

r4_full.to_csv("./dist/r4_full.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... r4_full.csv")
r4_no_disc.to_csv("./dist/r4_no_disc.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... r4_no_dics.csv")

r4_full
# Out:
# output... r4_full.csv
# output... r4_no_dics.csv
#     タブ名 第1層イニシャル             第1層  \
# 0    プロ       PR     プロフェッショナリズム
# 1    プロ       PR     プロフェッショナリズム
# 2    プロ       PR     プロフェッショナリズム
# 3    プロ       PR     プロフェッショナリズム
# 4    プロ       PR     プロフェッショナリズム
# ..   ..      ...             ...
# 816  社会       SO  社会における医療の役割の理解
# 817  社会       SO  社会における医療の役割の理解
# 818  社会       SO  社会における医療の役割の理解
# 819  社会       SO  社会における医療の役割の理解
# 820  社会       SO  社会における医療の役割の理解
#
#                                                  第1層説明  \
# 0    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 1    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 2    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 3    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 4    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# ..                                                 ...
# 816  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 817  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 818  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 819  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 820  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
#
#                                                 編集用シート             第2層  \
# 0    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 1    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 2    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 3    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 4    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# ..                                                 ...             ...
# 816  https://docs.google.com/spreadsheets/d/10J6QQh...   国内外の視点から捉える医療
# 817  https://docs.google.com/spreadsheets/d/10J6QQh...   国内外の視点から捉える医療
# 818  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 819  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 820  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
#
#                                                  第2層説明 第2層メモ  \
# 0               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 1               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 2               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 3               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 4               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# ..                                                 ...   ...
# 816             国内、及び、国際社会の中で規定される医療の役割と医療体制について概説できる。   NaN
# 817             国内、及び、国際社会の中で規定される医療の役割と医療体制について概説できる。   NaN
# 818  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
# 819  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
# 820  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
#
#                   第3層                                                第4層  \
# 0                 誠実さ                      どのように行動すれば患者や社会に対して誠実に振る舞えるか？
# 1                 誠実さ                社会から信頼される専門職集団であるためにはどのように行動すればよいか？
# 2                 誠実さ                             どのように行動すれば守秘義務を遵守できるか？
# 3                  省察                         どのようにすれば自分自身の限界を適切に認識できるか？
# 4                  省察             他者からのフィードバックを受け入れられるにはどのような心持ちでいればよいか？
# ..                ...                                                ...
# 816  グルーバルヘルスの役割や医療体制  UHC(Universal health coverage)とは何かを概説し、各国の医療制度...
# 817  グルーバルヘルスの役割や医療体制                              保健関連SDGや国際援助組織を概説できる。
# 818       社会科学と医療との関係        社会科学（主に医療人類学や医療社会学）の基本的な視点・方法・理論を用いることができる。
# 819       社会科学と医療との関係   医療に関する諸事象をシステム論の観点から社会の諸制度との関わりのなかで捉え、構造的に説明できる。
# 820       社会科学と医療との関係  人びとの生活の場において健康・病気・死とそれらをめぐる医療がどのようにとらえられているかを探...
#
#                                                     メモ  \
# 0    プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムでは「医...
# 1    プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムでは「医...
# 2    プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムでは「医...
# 3    プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムでは「医...
# 4    新設,プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムで...
# ..                                                 ...
# 816                                                NaN
# 817                                                NaN
# 818                             部会からの提案を一部修正した案を採用（春田）
# 819                             部会からの提案を一部修正した案を採用（春田）
# 820                             部会からの提案を一部修正した案を採用（春田）
#
#                          H28対応項目
# 0                  A-01-03-na-01
# 1                  A-01-03-na-01
# 2                  A-04-02-na-07
# 3                  A-01-03-na-04
# 4                            NaN
# ..                           ...
# 816  B-01-09-na-01,B-01-09-na-01
# 817  B-01-09-na-01,B-01-09-na-01
# 818               B-04-01-na-01,
# 819               B-04-01-na-08,
# 820               B-04-01-na-02,
#
# [821 rows x 12 columns]

# %%
import csv
import pandas as pd

r4_l1_draft=pd.read_csv("./raw/sheets/R4コアカリ提出用/第1層.csv")

r4_l1_draft.to_csv("./dist/output/outcomes_l1.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... ./dist/output/outcomes_l1.csv")

columns=["第1層","第2層","第2層説明","第3層","第4層","メモ","UID","H28対応項目"]
r4_l234_draft = pd.DataFrame(data=[],columns=columns)
r4_l2 =  pd.DataFrame(data=[],columns=[])
tabs=r4_l1_draft["タブ名"]
for index, row in r4_l1_draft.iterrows():
    r4_l34_unit=pd.read_csv(f"./raw/sheets/{row.タブ名}編集用/第2から4層.csv")
    r4_l2_unit=pd.read_csv(f"./raw/sheets/{row.タブ名}編集用/第2層.csv")
    r4_l2 = pd.concat([r4_l2,r4_l2_unit])
    r4_l34_unit["第1層"] = row.第1層
    r4_l34_unit = pd.merge(r4_l34_unit,r4_l2_unit,how="left",on="第2層")
    r4_l234_draft=pd.concat([r4_l234_draft,r4_l34_unit.loc[:,columns]])

r4_l2.to_csv("./dist/output/outcomes_l2.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... ./dist/output/outcomes_l2.csv")

r4_full_draft=pd.merge(r4_l1_draft,r4_l234_draft,how="outer",on="第1層")
r4_full_draft=r4_full_draft.dropna(subset=["第1層","第2層","第3層","第4層"])
r4_full_draft.to_csv("./dist/r4_draft.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... r4_draft.csv")
r4_full_draft.loc[:,["第1層","第2層","第3層","第4層","UID","H28対応項目"]].to_csv("./dist/output/outcomes.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... outcomes.csv")

r4_full_draft
# Out:
# output... ./dist/output/outcomes_l1.csv
# output... ./dist/output/outcomes_l2.csv
# output... r4_draft.csv
# output... outcomes.csv
#     タブ名 第1層イニシャル             第1層  \
# 0    プロ       PR     プロフェッショナリズム
# 1    プロ       PR     プロフェッショナリズム
# 3    プロ       PR     プロフェッショナリズム
# 4    プロ       PR     プロフェッショナリズム
# 7    プロ       PR     プロフェッショナリズム
# ..   ..      ...             ...
# 887  社会       SO  社会における医療の役割の理解
# 888  社会       SO  社会における医療の役割の理解
# 889  社会       SO  社会における医療の役割の理解
# 890  社会       SO  社会における医療の役割の理解
# 892  社会       SO  社会における医療の役割の理解
#
#                                                  第1層説明  \
# 0    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 1    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 3    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 4    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 7    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# ..                                                 ...
# 887  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 888  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 889  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 890  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 892  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
#
#                                                 編集用シート             第2層  \
# 0    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 1    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 3    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 4    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 7    https://docs.google.com/spreadsheets/d/1So2CGT...            思いやり
# ..                                                 ...             ...
# 887  https://docs.google.com/spreadsheets/d/10J6QQh...   国内外の視点から捉える医療
# 888  https://docs.google.com/spreadsheets/d/10J6QQh...   国内外の視点から捉える医療
# 889  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 890  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 892  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
#
#                                                  第2層説明               第3層  \
# 0              誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす。               誠実さ
# 1              誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす。               誠実さ
# 3              誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす。                省察
# 4              誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす。                省察
# 7                     品格と礼儀を持って、他者を適切に理解し、思いやりを持って接する。              思いやり
# ..                                                 ...               ...
# 887             国内、及び、国際社会の中で規定される医療の役割と医療体制について概説できる。  グルーバルヘルスの役割や医療体制
# 888             国内、及び、国際社会の中で規定される医療の役割と医療体制について概説できる。  グルーバルヘルスの役割や医療体制
# 889  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...       社会科学と医療との関係
# 890  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...       社会科学と医療との関係
# 892  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...       社会科学と医療との関係
#
#                                                    第4層  \
# 0             患者や社会に対して誠実である行動とはどのようなものかを考え、そのように行動する。
# 1    社会から信頼される専門職集団の一員であるためにはどのように行動すべきかを考え、そのように行動...
# 3                                  自分自身の限界を適切に認識し行動する。
# 4                               他者からのフィードバックを適切に受け入れる。
# 7                                患者を含めた他者に思いやりをもって接する。
# ..                                                 ...
# 887  ユニバーサル・ヘルス・カバレッジ（UHC）の意義を理解し、世界各国の医療制度が抱える問題を例...
# 888           保健関連の国連開発目標や国際機関・国際協力に関わる組織・団体について概説できる。
# 889     日常生活や外来診療・在宅療養・入院・施設入所等において、健康・病気・死の捉え方を探索できる。
# 890    時代の流れ、社会の状況や諸制度との関わりのなかで医療に関する諸事象を捉え、構造的に説明できる。
# 892         個や集団に及ぼす文化・慣習による影響（コミュニケーションのあり方等）を理解している。
#
#                          メモ      UID                      H28対応項目
# 0                       NaN  JkxiJUs                A-01-03-na-01
# 1                       NaN  JkxiJUw                A-01-03-na-01
# 3                       NaN  JkxiJU4                A-01-03-na-04
# 4                       NaN  JkxiJU8                          NaN
# 7                       NaN  JkxiJVI                A-01-02-na-01
# ..                      ...      ...                          ...
# 887                     NaN  JkxoNwo  B-01-09-na-01,B-01-09-na-01
# 888                     NaN  JkxoNws  B-01-09-na-01,B-01-09-na-01
# 889  部会からの提案を一部修正した案を採用（春田）  JkxoNxQ               B-04-01-na-01,
# 890  部会からの提案を一部修正した案を採用（春田）  JkxoNxU               B-04-01-na-08,
# 892                      修正  JkxoNxc  C-05-07-na-07,C-05-07-na-08
#
# [593 rows x 12 columns]

# %%
import pandas as pd
import glob
import re
import csv
import os

os.makedirs(os.path.join("dist", "output", "tables"), exist_ok=True)
file_list = glob.glob(f"./raw/sheets/*編集用/別表-*.csv")
for file in file_list:
    name = re.search(r"別表\-(.+)\.csv",file).group(1)
    df = pd.read_csv(file,encoding="utf_8_sig")
    df.to_csv(f"./dist/output/tables/{name}.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
    print(f"output... ./dist/output/tables/{name}.csv")
# Out:
# output... ./dist/output/tables/●●症候.csv
# output... ./dist/output/tables/主要な臨床・画像検査.csv
# output... ./dist/output/tables/主要な臨床検査.csv
# output... ./dist/output/tables/主要症候.csv
# output... ./dist/output/tables/主要診療科.csv
# output... ./dist/output/tables/基本的臨床手技.csv
# output... ./dist/output/tables/基本的診療科.csv
# output... ./dist/output/tables/身体診察.csv
# output... ./dist/output/tables/知識.csv

# %%
import pandas as pd
import glob
import re
import csv
import os

r4_l1=pd.read_csv("./raw/sheets/R4コアカリ提出用/第1層.csv").loc[:,["タブ名","第1層"]]
os.makedirs(os.path.join("dist", "output", "tables"), exist_ok=True)
file_list = glob.glob(f"./raw/sheets/*編集用/行き先がないID.csv")
df = pd.DataFrame([],columns=[])
for file in file_list:
    name = re.search(r"([^\\\/]+)編集用",file).group(1)
    unit = pd.read_csv(file,encoding="utf_8_sig")
    print(name)
    unit["タブ名"]=name
    df= pd.concat([df,unit])

df=pd.merge(df,r4_l1,how="left",on="タブ名")
df.to_csv(f"./dist/output/deleted_or_moved.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print(f"output... ./dist/output/deleted_or_moved.csv")
# Out:
# コミュ
# プロ
# 情報
# 技能
# 生涯
# 知識
# 社会
# 科学
# 総合
# 連携
# output... ./dist/output/deleted_or_moved.csv
